# %%
import numpy as np
import time
from math import sqrt, pi, exp
import functools
import scipy
import matplotlib.pylab as pl
from varname import nameof


from utils.preconditioners import *
from utils.algorithms import *
from utils.functions import *

# %% [markdown]
# ### Test case "Gaussian"

# %%
# 
d = 2

# test case "Gaussian"
xmin = -4
xmax = 4
ymin= -4
ymax= 4

#m = np.asarray([0,0])
#K = np.diag([1,1])
#K_inv = np.linalg.inv(K)
#K_det = np.linalg.det(K)

#coe = 1.0 / ((2 * np.pi)**2 * K_det)**0.5
#I = lambda u: np.linalg.multi_dot([u.T,np.linalg.inv(K),u]) # does not work idny
#I = lambda u: coe * np.e ** (-0.5 * (K_inv[0,0]*(u[0]-m[0])**2 \
#                + (K_inv[0,1] + K_inv[1,0])*(u[0]-m[0])*(u[1]-m[1]) + K_inv[1,1]*(u[1]-m[1])**2))


# potential function

y=0
sigNoise = 0.5
sigPrior = 2

G = lambda u: (u[1])**2+(u[0])**2
Phi = lambda u: 0.5/(sigNoise**2)*(G(u)-y)**2 #likelihood

# potential function
I = lambda u: Phi(u) + 0.5/(sigPrior**2)*np.linalg.norm(u,axis=0)**2

# C0MPUTE SIGMA POSTERIOR

K_inv = np.eye(d,d)*sigPrior + np.eye(d,d)*sigNoise
K = np.linalg.solve(K_inv,np.eye(d,d))

# %%
K
# Out:
# array([[0.4, 0. ],
#        [0. , 0.4]])

# %% [markdown]
# ### Try algorithms

# %%
# parameters of all the algorithms

J = 100  # number of particles 
N_sim = 100 # number of iterations
d = 2 # dimension
tau = 0.01 # step size
u0 = np.random.normal(0,1,(d,J)) # initial position of the particles of shape (dimension, nb of particles)

# parameters of our algorithm
const = 1.5

# %%
u0s = np.linspace(xmin,xmax,150)
u1s = np.linspace(ymin,ymax,150)
U0, U1 = np.meshgrid(u0s,u1s)
U = np.stack((U0,U1))


plt.figure()
plt.contourf(U0, U1, np.exp(-I(U)), 10)
plt.scatter(u0[0],u0[1])
plt.plot()
plt.gca().set_aspect('equal')
plt.title("Posterior distribution and initialization")
# Out:
# Text(0.5, 1.0, 'Posterior distribution and initialization')

# %%
u0.shape
# Out:
# (2, 100)

# %%
us_list = np.zeros((d, J, N_sim))

# %%
start_time = time.time()

us_list_ULA = run_ULA(I, N_sim, u0, tau)

print(f"ULA: {time.time()-start_time} seconds")
# Out:
# ULA: 7.201840162277222 seconds

# %%
# EKS (ALDI with gradient)

start_time = time.time()

us_list_ALDI = run_ALDI_with_gradient(I, N_sim, u0, tau)

print(f"ALDI with gradient: {time.time()-start_time} seconds")
# Out:
# ALDI with gradient: 8.235920906066895 seconds

# %%
# Non reversible EKS (our algorithm) v2

# parameters of all the algorithms

#J =   # number of particles 
N_sim_ALDINR = 500 # number of iterations
tau_ALDINR = 1e-4
#u0 = np.random.normal(0,0.5,(2,J)) # initial position of the particles

# parameters of our algorithm
const = 1.5 

start_time = time.time()

us_list_ALDINR, means, covariances, preconditioners = run_ALDINR(I, N_sim_ALDINR, u0, tau_ALDINR, const)
    
print(f"ALDI: {time.time()-start_time} seconds")

us_list_ALDINR.tofile('save_data/ALDINR_J='+str(J)+'_tau='+str(tau_ALDINR)+'_c='+str(const)+'.dat')
means.tofile('save_data/means_ALDINR_J='+str(J)+'_tau='+str(tau_ALDINR)+'_c='+str(const)+'.dat')
covariances.tofile('save_data/covariances_ALDINR_J='+str(J)+'_tau='+str(tau_ALDINR)+'_c='+str(const)+'.dat')
preconditioners.tofile('save_data/preconditioners_ALDINR_J='+str(J)+'_tau='+str(tau_ALDINR)+'_c='+str(const)+'.dat')

#us_list_ALDINR2 = np.fromfile('save_data/ALDINR_5000.dat', dtype=int)
#us_list_ALDINR == us_list_ALDINR2
# Out:
# iter
# 0
# 0.849189515703336
# 0.8409724429303962
# 0.8342775099260725
# 0.8200681244791481
# 0.8079894536738128
# 0.7945683975053894
# 0.7861467603108074
# 0.7741314284628633
# 0.7647409282322287
# 0.75609598953226
# 0.7428798678342801
# 0.736822128405929
# 0.7256041731424911
# 0.7229335393588996
# 0.7219313563279813
# 0.7123372005079414
# 0.7083637373306882
# 0.7021393197579959
# 0.6997625253199095
# 0.6934473996020952
# 0.689454067187549
# 0.679940829384131
# 0.6712165772834182
# 0.667638197869496
# 0.6677972662427714
# 0.6593523369885205
# 0.6559047368297383
# 0.6493215059020863
# 0.644298692144597
# 0.6450584918536945
# 0.639652159692161
# 0.6352532891303394
# 0.6303298602503172
# 0.6260369328876413
# 0.6172213116414053
# 0.6113722195302046
# 0.6018877523814572
# 0.5957681793499331
# 0.5933103879588564
# 0.5872828852975743
# 0.5834465583693971
# 0.5775041135119823
# 0.5788618919135111
# 0.576826019216913
# 0.57266719948998
# 0.5615202642493651
# 0.5526930563815865
# 0.5532564299549954
# 0.5473440831788019
# 0.5434564662307094
# 0.5438759353359108
# 0.5387575705458486
# 0.536123533920604
# 0.535309623752391
# 0.5320711381203214
# 0.5250785806307454
# 0.5191922420824815
# 0.511133165368017
# 0.5120142825529027
# 0.5104093157583716
# 0.5041785290211188
# 0.5006113646830184
# 0.4991440860220177
# 0.49916496084644346
# 0.4935323667825391
# 0.48933085607741894
# 0.4875766767454728
# 0.4891032476790386
# 0.49203104746216064
# 0.489516740174343
# 0.48969674168002597
# 0.49120968693819034
# 0.4920138269671707
# 0.4868900807044457
# 0.4843217180712561
# 0.48418251434739873
# 0.48717235436922474
# 0.4849184182962765
# 0.4854435032911863
# 0.48030383515707736
# 0.4767497226996736
# 0.4739517262063698
# 0.4682900454450969
# 0.46197113646398863
# 0.46467389935198367
# 0.4620577204745435
# 0.46285902995513883
# 0.4644845052766839
# 0.46011905858942503
# 0.4585761547107445
# 0.4529528304186278
# 0.44954534974777705
# 0.44452239130049453
# 0.44439435745844236
# 0.4450259031029298
# 0.4445579919774224
# 0.44376563369724553
# 0.44532338836846136
# 0.44418240466795145
# 0.4424199525109635
# iter
# 100
# 0.43836230659834186
# 0.4402173376908306
# 0.44340342220301565
# 0.44280731753309177
# 0.44062962869270056
# 0.44089143683233395
# 0.44250414075278116
# 0.43975065955375303
# 0.43549520098137723
# 0.4344911576125765
# 0.43793020307846253
# 0.43762633671592505
# 0.4408853424190083
# 0.4378398022624326
# 0.43689992984837817
# 0.439827511591452
# 0.43768128731963823
# 0.43365939526750336
# 0.4333955572319519
# 0.4354518784145681
# 0.43123308511757824
# 0.4300372507856534
# 0.4258177936186479
# 0.42433727743482785
# 0.4200829154304896
# 0.4208034774096515
# 0.3494356424742976
# 0.3486997808189763
# 0.35058283807535673
# 0.3490187658061278
# 0.346998873308192
# 0.3492897280633866
# 0.34466407522895354
# 0.3444887930674626
# 0.345475863181982
# 0.34306057723877603
# 0.3443413290092938
# 0.34493258889303074
# 0.3468431995424137
# 0.3435026813204845
# 0.34505979457193203
# 0.3450342625209279
# 0.34383979252240876
# 0.3430117932682488
# 0.342295943381976
# 0.34359591400313616
# 0.34294072743315707
# 0.3429968598244137
# 0.3448847706744173
# 0.3440730181574521
# 0.3407517793232976
# 0.33626180609386835
# 0.3344905370208955
# 0.33169881316595656
# 0.3342360987307739
# 0.33306573473400797
# 0.3306469716996702
# 0.33042270578947774
# 0.33211093998533864
# 0.32988119496542967
# 0.3302803923482958
# 0.3286015333286327
# 0.329481005301706
# 0.32511588724705015
# 0.3262682671196788
# 0.32364371427252503
# 0.3223474400425349
# 0.3210300038041442
# 0.32123344623369654
# 0.3203117064826289
# 0.3195227663745761
# 0.3194429976658838
# 0.31772012887900547
# 0.3131311742723056
# 0.3138341968193464
# 0.31475232050505897
# 0.3144087594937472
# 0.3116257514404211
# 0.31453130457762435
# 0.3111669206764839
# 0.3083755496165744
# 0.3031168302723914
# 0.3018662962506398
# 0.3008170693535075
# 0.3025879343828057
# 0.3028264453806284
# 0.3024662012275536
# 0.30251794366125434
# 0.3016292159691285
# 0.3009601735129956
# 0.302606276594929
# 0.3042199506331168
# 0.30418789787997413
# 0.30233117313260727
# 0.30106007414869784
# 0.3005902655231185
# 0.30230589795759005
# 0.2979193284274623
# 0.29968717050209104
# 0.29754786041761716
# 0.300572854227215
# 0.2988178574541431
# 0.2982355144133068
# 0.3011741645134397
# ALDI: 34.574418783187866 seconds

# %%
# save results

#us_list_ULA.tofile('save_data/ULA.dat')
#us_list_ULA2 = np.fromfile('save_data/ULA.dat', dtype=int)
#us_list_ULA == us_list_ULA2

#us_list_ALDINR.tofile('save_data/ALDINR_5000.dat')
#us_list_ALDINR2 = np.fromfile('save_data/ALDINR_5000.dat', dtype=int)
#us_list_ALDINR == us_list_ALDINR2

# %%
# plot results

N_burnin = 0

name = nameof(us_list_ULA).lstrip('us_list')
plot_results(I, us_list_ULA, name)

name = nameof(us_list_ALDI).lstrip('us_list')
plot_results(I, us_list_ALDI, name)
    
name = nameof(us_list_ALDINR).lstrip('us_list')
plot_results(I, us_list_ALDINR, name)

# %%
us_list_ALDINR[0,:,:].flatten()

# %%
np.max(us_list_ALDINR[0,:,N_burnin:].flatten())

# %%
np.min(us_list_ALDINR[0,:,N_burnin:].flatten())

# %%
np.max(us_list_ALDI[0,:,N_burnin:].flatten())

# %%
np.min(us_list_ALDI[0,:,N_burnin:].flatten())

# %%
plt.hist(us_list_ALDINR[0,:,N_burnin:].flatten())

# %%
plt.hist(us_list_ALDI[0,:,N_burnin:].flatten())

# %%
us_list_ALDI[0,:,N_burnin:].flatten()

# %%
plt.hist2d(us_list_ALDINR[0,:,N_burnin:].flatten(),us_list_ALDINR[1,:,N_burnin:].flatten(),bins=200)
plt.show()

# %%
plt.hist2d(us_list_ALDI[0,:,N_burnin:].flatten(),us_list_ALDI[1,:,N_burnin:].flatten(),bins=200)
plt.show()

# %%
dist_M[1]
